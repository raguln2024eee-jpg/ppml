# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original DataFrame with NaN
#          one       two     three
# a  0.486800 -0.969869 -0.458763
# b       NaN       NaN       NaN
# c  0.281512  0.597128 -0.657981
# d  0.960789 -0.313172  0.289602
# e       NaN       NaN       NaN
# f -0.721684  0.325695  0.137349
#
#
# Dropped DataFrame
#          one       two     three
# a  0.486800 -0.969869 -0.458763
# c  0.281512  0.597128 -0.657981
# d  0.960789 -0.313172  0.289602
# f -0.721684  0.325695  0.137349

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original DataFrame with NaN
#          one       two     three
# a  0.964881 -0.192814  0.416064
# b       NaN       NaN       NaN
# c -0.206950 -0.783665 -0.085230
# d -0.030291  0.760189 -1.109588
# e       NaN       NaN       NaN
# f -0.067600 -0.299212 -0.008631
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.964881 -0.192814  0.416064
# b  0.000000  0.000000  0.000000
# c -0.206950 -0.783665 -0.085230
# d -0.030291  0.760189 -1.109588
# e  0.000000  0.000000  0.000000
# f -0.067600 -0.299212 -0.008631

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame:
#          one       two     three
# a  0.848160  0.965387  0.223127
# b       NaN       NaN       NaN
# c  0.117437  0.330464  0.489517
# d -1.957716 -0.656481  0.108140
# e       NaN       NaN       NaN
# f  1.092612  1.327936  0.334334
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-Filled with the Background value:\n")
print(df.fillna(method='bfill'))
# Out:
# Original DataFrame:
#          one       two     three
# a  1.203465  1.391865 -0.891622
# b       NaN       NaN       NaN
# c -1.443276  0.703783 -0.195692
# d  0.537239  0.115672  0.144514
# e       NaN       NaN       NaN
# f  1.987100  0.292874 -0.473248
#
# Nan-Filled with the Background value:
#
#         one       two     three
# a  1.203465  1.391865 -0.891622
# b -1.443276  0.703783 -0.195692
# c -1.443276  0.703783 -0.195692
# d  0.537239  0.115672  0.144514
# e  1.987100  0.292874 -0.473248
# f  1.987100  0.292874 -0.473248
# /tmp/ipython-input-796649510.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
